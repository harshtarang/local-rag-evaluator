# %%
import pandas as pd
model = "mistral"
prompt_type = "basic"
num_chunks = 1
df = pd.read_json(f"../answers/rag/{model}/evaluation_{prompt_type}_{num_chunks}.json")
print(df['ground_truth'].tolist())
# Out:
# ["The Emergency Response team coordinates the university's response to student emergencies and crises.", 'Visitors to the University of Florida can expect to experience information sessions and walking tours of the campus as mentioned in the context.', 'The important deadlines for submitting application materials to the University of Florida (UF) Admissions for prospective freshmen in the 2023-24 academic year are as follows: \n\nApplication Opens: August 8\nApplication Due: November 1\nStudent Self-Reported Academic Record (SSAR): November 15\nSubmit Official Test Scores: December 1\nFreshman Admissions Decisions: February 23\nConfirm Enrollment: May 1\nSend Official Transcripts: July 15.', 'Prospective freshmen must submit their official transcripts to the UF Office of Admissions by July 15 in order to finalize their enrollment at UF for the 2023-24 academic year.', 'Parents of dependent undergraduate students at UF can apply for educational loans through the Federal Direct PLUS loan program. The context does not provide specific information on how to apply, but it mentions that more information can be found on the SFA website (<http://www.sfa.ufl.edu/programs/loans/>).', 'Users can navigate to the Item Types report in the Student Information System by following these steps: 1. Click the NavBar icon 2. Click Main Menu 3. Click Enterprise Reporting 4. Click Access Reporting 5. Click Public Folder 6. Click Student Information 7. Click Student Financials 8. Click Reference 9. Click Item Types. Then, they need to search for the report using the DeptFlex (full or partial) in the ChartField Starts with the value: textbox and click Finish. This will display a list of the available scholarships available for awarding by the specific department.', 'The Division of Student Life at the University of Florida offers various facilities and services to students including, but not limited to, the Career Connections Center, Center for Inclusion & Multicultural Engagement, Center for New Student & Family Programs, Counseling and Wellness Center, David and Wanda Brown Center for Leadership & Service, Dean of Students Ofﬁce, Disability Resource Center, GatorWell Health Promotion Services, Housing and Residence Life, J. Wayne Reitz Union, Machen Florida Opportunity Scholars Program, Off Campus Life, Recreational Sports, Student Activities & Involvement, Student Government Advising & Operations, Sorority & Fraternity Life, and Student Legal Services. Additionally, the division oversees facilities such as Newell Hall, Reitz Student Union, Ben Hill Grifﬁn Stadium, Florida Museum of Natural History, Harn Museum of Art, and O’Connell Center.', 'The University of Florida Police Department (UFPD) provides various services to ensure campus safety and security, including maintaining a presence on campus with over 90 fully certified and sworn officers who patrol the UF campus and its surrounding properties 24 hours per day. The department also has a Criminal Investigations Division employing highly trained detectives to investigate any reported crime on campus. Officers are equipped with contemporary crime-fighting techniques and tools. Additionally, the Community Services Division provides information regarding personal and property protection through classes, programs, and documents.', 'Establishing a new center or institute at University of Florida can contribute to public service by providing greater focus and depth to a research area, designing courses, developing interdisciplinary graduate programs, attracting postdoctoral fellows, creating a lecture series, establishing a core service facility, and providing external funding. Activities specifically planned for public service may include community outreach programs, public seminars and workshops, collaborative research on issues of public importance, and the development of resources and services that address the needs of specific populations or communities.', 'The Florida Voluntary Prekindergarten  ...

# %%
data_dict = {
'question': df['question'].tolist(),
'ground_truth': df['ground_truth'].tolist(),
'contexts': df['contexts'].tolist(),
'answer': df['answer'].tolist(),
'evolution_type': df['evolution_type'].tolist(),
'episode_done': df['episode_done'].tolist()

}

# %%
from datasets import Dataset 

dataset = Dataset.from_dict(data_dict)
dataset
# Out:
# Dataset({
#     features: ['question', 'ground_truth', 'contexts', 'answer', 'evolution_type', 'episode_done'],
#     num_rows: 12
# })

# %%
from ragas.metrics import (
    context_relevancy,
    faithfulness,
    answer_relevancy,
    answer_similarity,
    answer_correctness,
    context_precision,
    context_recall
)
from ragas.metrics.critique import harmfulness

# %%
# LangChain supports many other chat models. Here, we're using Ollama
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# supports many more optional parameters. Hover on your `ChatOllama(...)`
# class to view the latest available supported parameters
llm = ChatOllama(model="llama3:8b")
prompt = ChatPromptTemplate.from_template("Tell me a short joke about {topic}")

# using LangChain Expressive Language chain syntax
# learn more about the LCEL on
# /docs/concepts/#langchain-expression-language-lcel
chain = prompt | llm | StrOutputParser()

# for brevity, response is printed in terminal
# You can use LangServe to deploy your application for
# production
print(chain.invoke({"topic": "Space travel"}))
# Out:
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!

# %%
from ragas.llms import LangchainLLMWrapper

mistral_wrapper = LangchainLLMWrapper(langchain_llm=llm)
faithfulness.llm = mistral_wrapper
answer_relevancy.llm = mistral_wrapper
context_relevancy.llm = mistral_wrapper
answer_similarity.llm = mistral_wrapper
answer_correctness.llm = mistral_wrapper
harmfulness.llm = mistral_wrapper
context_precision.llm = mistral_wrapper
context_recall.llm = mistral_wrapper

# %%
# evaluate
from ragas import evaluate
from langchain_community.embeddings.fastembed import FastEmbedEmbeddings
fast_embeddings = FastEmbedEmbeddings(model_name="BAAI/bge-base-en")

result = evaluate(
    dataset, 
     metrics=[
        context_precision,
        context_relevancy,
        answer_similarity
    ],
    embeddings=fast_embeddings,
    raise_exceptions=True
)

result
# Out:
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# {'context_precision': 0.5833, 'context_relevancy': 0.4818, 'answer_similarity': 0.9342}

# %%
import json

with open(f"result_{model}_{prompt_type}_{num_chunks}.json", "w") as f:
    json.dump(result, f)

# %%
df = result.to_pandas()
df.head(12)
# Out:
#                                              question  \
# 0   Who coordinates the university's response to s...
# 1   What can visitors to the University of Florida...
# 2   What are the important deadlines for submittin...
# 3   What is the deadline for prospective freshmen ...
# 4   How can parents apply for educational loans fo...
# 5   How can users find the available financial aid...
# 6   What are some facilities and services offered ...
# 7   What services does the University of Florida P...
# 8   How does establishing a new center or institut...
# 9   What program offers free pre-K education for a...
# 10  What role do information sessions play in camp...
# 11  What resources does the UF Libraries offer for...
#
#                                          ground_truth  \
# 0   The Emergency Response team coordinates the un...
# 1   Visitors to the University of Florida can expe...
# 2   The important deadlines for submitting applica...
# 3   Prospective freshmen must submit their officia...
# 4   Parents of dependent undergraduate students at...
# 5   Users can navigate to the Item Types report in...
# 6   The Division of Student Life at the University...
# 7   The University of Florida Police Department (U...
# 8   Establishing a new center or institute at Univ...
# 9   The Florida Voluntary Prekindergarten Educatio...
# 10  Information sessions are an essential part of ...
# 11  The UF Libraries offer various resources for s...
#
#                                              contexts  \
# 0   [next to the Reitz Union. The Welcome Center i...
# 1   [next to the Reitz Union. The Welcome Center i...
# 2   [FRESHMAN DATES & DEADLINES Keep this list of ...
# 3   [FRESHMAN DATES & DEADLINES Keep this list of ...
# 4   [Work-Study jobs may be awarded by SFA to stud...
# 5   [Organizations:  https://studentinvolvement.uf...
# 6   [next to the Reitz Union. The Welcome Center i...
# 7   [for all students, faculty and staff, and camp...
# 8   [public schools; public-private partnerships);...
# 9   [next to the Reitz Union. The Welcome Center i...
# 10  [next to the Reitz Union. The Welcome Center i...
# 11  [Gators thrive and have a transformative stude...
#
#                                                answer evolution_type  \
# 0   The University of Florida does not provide spe...         simple
# 1   Visitors to the University of Florida can expe...         simple
# 2   Here are the important deadlines for submittin...         simple
# 3   The deadline for prospective freshmen to submi...         simple
# 4   Parents of dependent undergraduate students at...         simple
# 5   Users can find the available financial aid ite...         simple
# 6   The Division of Student Life at the University...         simple
# 7   The University of Florida Police Department (U...         simple
# 8   Establishing a new center or institute at the ...         simple
# 9   The Florida Voluntary Prekindergarten Educatio...         simple
# 10  Information sessions are an essential part of ...         simple
# 11  The UF Libraries offer several resources for s...         simple
#
#     episode_done  context_precision  context_relevancy  answer_similarity
# 0           True               0.00           0.114286           0.886199
# 1           True               0.70           0.041667           0.910983
# 2           True               1.00           0.038462           0.987636
# 3           True               1.00           0.092308           0.982907
# 4           True               1.00           0.087719           0.979180
# 5           True               0.20           0.049180           0.934156
# 6           True               1.00           0.114754           0.973612
# 7           True               1.00           0.087500           0.969795
# 8           True               1.00           0.054054           0.954222
# 9           True               0.50           0.078125           1.000000
# 10          True               1.00           0.054795           0.970744
# 11          True               0.25           0.083333           0.933905

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap


heatmap_data = df[['context_precision', 'context_relevancy', 'answer_similarity']]

cmap = LinearSegmentedColormap.from_list('green_red', ['red', 'green'])

plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", linewidths=.5, cmap=cmap)

plt.yticks(ticks=range(len(df['question'])), labels=df['question'], rotation=0)

plt.show()
